# %%
import json
import pandas as pd
from pandas import json_normalize
URL = "C:\\Users\\jawar\\Downloads\\SIMCHS_2026_03 (4).json"

# %%
#Configuración de Visualizaciones de los DataFrame de Pandas
pd.set_option("display.max_rows", None) # Mostrar todas las filas
pd.set_option("display.max_columns", None) # Mostrar todas las columnas
pd.set_option("display.max_colwidth", None)# Ajustar el ancho de las columnas
pd.set_option("display.width", None) # Evitar que se corte horizontalmente
pd.options.display.float_format = "{:.6f}".format #Damos formato a las salidas del DF

# %%
# Cargar el archivo JSON
with open(URL, "r", encoding="utf-8") as f:
    data = json.load(f)

# Normalizar: expandir la lista de 'respuestas' y traer los metadatos
df = pd.json_normalize(
    data,
    record_path=["respuestas"],   # lista que queremos expandir
    meta=[
        "id",
        "estado",
        ["tiempo", "inicio"],
        ["tiempo", "fin"],
        ["tiempo", "duracionSegundos"],
        ["progreso", "respondidas"],
        ["progreso", "total"],
        ["progreso", "porcentaje"],
        ["datosGenerales", "rangoEdad"],
        ["datosGenerales", "genero"],
        ["datosGenerales", "nivelEducativo"],
        ["datosGenerales", "tipoSalud"],
        ["datosGenerales", "municipio"],
        ["datosGenerales", "musica"]
    ]
)

# %%
valores = list(df["valor"])

for i in range(0, len(valores), 10):
    print(f'{i} - {valores[i:i+10]}')
# Out:
# 0 - [5, 4, 5, 4, 4, 2, 4, 5, 5, 1]
# 10 - [4, 4, 4, 5, 2, 1, 4, 5, 4, 3]
# 20 - [4, 5, 3, 4, 4, 5, 4, 2, 4, 5]
# 30 - [2, 4, 4, 2, 4, 4, 2, 5, 5, 4]
# 40 - [5, 5, 4, 5, 4, 5, 3, 4, 5, 4]
# 50 - [2, 3, 4, 2, 2, 4, 1, 4, 4, 2]
# 60 - [4, 5, 4, 5, 4, 2, 2, 1, 2, 1]
# 70 - [4, 5, 3, 2, 5, 2, 5, 5, 2, 4]
# 80 - [5, 5, 5, 1, 5, 5, 5, 2, 3, 2]
# 90 - [4, 5, 4, 1, 2, 4, 1, 1, 4, 5]
# 100 - [4, 5, 5, 1, 5, 4, 4, 2, 5, 5]
# 110 - [5, 4, 4, 2, 4, 4, 3, 2, 4, 3]
# 120 - [5, 4, 5, 2, 5, 5, 4, 4, 5, 4]
# 130 - [2, 4, 2, 2, 5, 4, 2, 4, 4, 4]
# 140 - [2, 4, 2, 3, 4, 4, 5, 2, 4, 5]

# %% [markdown]
# ## Analisis por Array respuestas

# %%
Array_Respuesta = {"item":1,"pregunta":" Analizo diferentes perspectivas antes de tomar una decisión","valor":3,"nivel":" N1","dimension":"Cognitiva","tipo":"Normal"},{"item":2,"pregunta":" Cuestiono la información antes de aceptarla como verdadera","valor":4,"nivel":" N1","dimension":"Cognitiva","tipo":"Normal"},{"item":3,"pregunta":" Reflexiono sobre mis propios pensamientos","valor":4,"nivel":" N1","dimension":"Cognitiva","tipo":"Normal"},{"item":4,"pregunta":" Identifico errores en mi razonamiento","valor":4,"nivel":" N1","dimension":"Cognitiva","tipo":"Normal"},{"item":5,"pregunta":" Busco coherencia lógica en lo que pienso","valor":4,"nivel":" N1","dimension":"Cognitiva","tipo":"Normal"},{"item":6,"pregunta":" Cambio de opinión cuando la evidencia lo justifica","valor":3,"nivel":" N1","dimension":"Cognitiva","tipo":"Normal"},{"item":7,"pregunta":" Me dejo llevar por ideas sin analizarlas","valor":2,"nivel":" N1 ","dimension":"Cognitiva","tipo":"Invertida"},{"item":8,"pregunta":" Evalúo consecuencias antes de actuar","valor":4,"nivel":" N1","dimension":"Cognitiva","tipo":"Normal"},{"item":9,"pregunta":" Organizo mentalmente la información compleja","valor":4,"nivel":" N1","dimension":"Cognitiva","tipo":"Normal"},{"item":10,"pregunta":" Me cuesta estructurar mis pensamientos","valor":2,"nivel":" N1 ","dimension":"Cognitiva","tipo":"Invertida"},{"item":11,"pregunta":" Identifico con claridad lo que siento","valor":4,"nivel":" N2","dimension":"Emocional","tipo":"Normal"},{"item":12,"pregunta":" Comprendo por qué me siento como me siento","valor":4,"nivel":" N2","dimension":"Emocional","tipo":"Normal"},{"item":13,"pregunta":" Expreso mis emociones de forma adecuada","valor":4,"nivel":" N3","dimension":"Emocional","tipo":"Normal"},{"item":14,"pregunta":" Reconozco cuando una emoción influye en mi juicio","valor":4,"nivel":" N2","dimension":"Emocional","tipo":"Normal"},{"item":15,"pregunta":" Me desbordo fácilmente emocionalmente","valor":4,"nivel":" N2 ","dimension":"Emocional","tipo":"Invertida"},{"item":16,"pregunta":" Mantengo estabilidad emocional ante presión","valor":3,"nivel":" N2","dimension":"Emocional","tipo":"Normal"},{"item":17,"pregunta":" Puedo calmarme cuando estoy alterado","valor":3,"nivel":" N3","dimension":"Emocional","tipo":"Normal"},{"item":18,"pregunta":" Evito reconocer emociones negativas","valor":4,"nivel":" N2 ","dimension":"Emocional","tipo":"Invertida"},{"item":19,"pregunta":" Comprendo emociones complejas en mí","valor":4,"nivel":" N2","dimension":"Emocional","tipo":"Normal"},{"item":20,"pregunta":" Actúo impulsivamente por emoción","valor":3,"nivel":" N3 ","dimension":"Conciencia","tipo":"Invertida"},{"item":21,"pregunta":" Soy consciente del impacto de mis acciones","valor":4,"nivel":" N1","dimension":"Conciencia","tipo":"Normal"},{"item":22,"pregunta":" Reflexiono sobre mis decisiones diarias","valor":4,"nivel":" N1","dimension":"Conciencia","tipo":"Normal"},{"item":23,"pregunta":" Actúo de manera automática sin pensar","valor":3,"nivel":" N3 ","dimension":"Conciencia","tipo":"Invertida"},{"item":24,"pregunta":" Identifico cómo influyo en mi entorno","valor":4,"nivel":" N1","dimension":"Conciencia","tipo":"Normal"},{"item":25,"pregunta":" Me cuestiono sobre mi forma de vivir","valor":5,"nivel":" N1","dimension":"Conciencia","tipo":"Normal"},{"item":26,"pregunta":" Reconozco mis fortalezas y debilidades","valor":5,"nivel":" N1","dimension":"Conciencia","tipo":"Normal"},{"item":27,"pregunta":" Ajusto mi comportamiento cuando es necesario","valor":4,"nivel":" N3","dimension":"Conciencia","tipo":"Normal"},{"item":28,"pregunta":" Vivo sin analizar mis experiencias","valor":3,"nivel":" N1 ","dimension":"Conciencia","tipo":"Invertida"},{"item":29,"pregunta":" Aprendo de mis errores","valor":4,"nivel":" N3","dimension":"Conciencia","tipo":"Normal"},{"item":30,"pregunta":" Me observo internamente con frecuencia","valor":4,"nivel":" N1","dimension":"Conciencia","tipo":"Normal"},{"item":31,"pregunta":" Reconozco patrones repetitivos en mí","valor":4,"nivel":" N1","dimension":"Autoconciencia","tipo":"Normal"},{"item":32,"pregunta":" Identifico mis valores personales","valor":5,"nivel":" N1","dimension":"Autoconciencia","tipo":"Normal"},{"item":33,"pregunta":" Comprendo mis motivaciones internas","valor":5,"nivel":" N1","dimension":"Autoconciencia","tipo":"Normal"},{"item":34,"pregunta":" Me resulta difícil entenderme","valor":5,"nivel":" N1 ","dimension":"Autoconciencia","tipo":"Invertida"},{"item":35,"pregunta":" Sé cómo reacciono ante presión","valor":4,"nivel":" N1","dimension":"Autoconciencia","tipo":"Normal"},{"item":36,"pregunta":" Identifico mis límites personales","valor":5,"nivel":" N1","dimension":"Autoconciencia","tipo":"Normal"},{"item":37,"pregunta":" Actúo sin conocer mis verdaderas intenciones","valor":3,"nivel":" N1 ","dimension":"Autoconciencia","tipo":"Invertida"},{"item":38,"pregunta":" Evalúo mi comportamiento después de actuar","valor":4,"nivel":" N1","dimension":"Autoconciencia","tipo":"Normal"},{"item":39,"pregunta":" Reconozco cuando estoy equivocado","valor":4,"nivel":" N3","dimension":"Autoconciencia","tipo":"Normal"},{"item":40,"pregunta":" Tengo claridad sobre quién soy","valor":5,"nivel":" N1","dimension":"Autoconciencia","tipo":"Normal"},{"item":41,"pregunta":" Comprendo cómo se sienten los demás","valor":5,"nivel":" N2","dimension":"Empatía","tipo":"Normal"},{"item":42,"pregunta":" Puedo ponerme en el lugar del otro","valor":5,"nivel":" N1","dimension":"Empatía","tipo":"Normal"},{"item":43,"pregunta":" Percibo cambios emocionales en otros","valor":4,"nivel":" N2","dimension":"Empatía","tipo":"Normal"},{"item":44,"pregunta":" Me cuesta entender emociones ajenas","valor":3,"nivel":" N2 ","dimension":"Empatía","tipo":"Invertida"},{"item":45,"pregunta":" Respondo con sensibilidad ante el dolor ajeno","valor":4,"nivel":" N3","dimension":"Empatía","tipo":"Normal"},{"item":46,"pregunta":" Escucho activamente a otros","valor":4,"nivel":" N3","dimension":"Empatía","tipo":"Normal"},{"item":47,"pregunta":" Evito involucrarme emocionalmente","valor":4,"nivel":" N2 ","dimension":"Empatía","tipo":"Invertida"},{"item":48,"pregunta":" Considero perspectivas diferentes a la mía","valor":4,"nivel":" N1","dimension":"Empatía","tipo":"Normal"},{"item":49,"pregunta":" Soy compasivo ante errores ajenos","valor":3,"nivel":" N3","dimension":"Empatía","tipo":"Normal"},{"item":50,"pregunta":" Me afecta emocionalmente el sufrimiento de otros","valor":3,"nivel":" N2","dimension":"Empatía","tipo":"Normal"},{"item":51,"pregunta":" Confío en mi intuición al decidir","valor":4,"nivel":" N1","dimension":"Intuición","tipo":"Normal"},{"item":52,"pregunta":" Percibo situaciones antes de que ocurran","valor":4,"nivel":" N1","dimension":"Intuición","tipo":"Normal"},{"item":53,"pregunta":" Detecto incongruencias sin explicación lógica inmediata","valor":3,"nivel":" N1","dimension":"Intuición","tipo":"Normal"},{"item":54,"pregunta":" Ignoro mis corazonadas","valor":3,"nivel":" N1 ","dimension":"Intuición","tipo":"Invertida"},{"item":55,"pregunta":" Mi intuición suele ser acertada","valor":4,"nivel":" N1","dimension":"Intuición","tipo":"Normal"},{"item":56,"pregunta":" Integro intuición y análisis racional","valor":3,"nivel":" N1","dimension":"Intuición","tipo":"Normal"},{"item":57,"pregunta":" Actúo sin escuchar señales internas","valor":3,"nivel":" N3 ","dimension":"Intuición","tipo":"Invertida"},{"item":58,"pregunta":" Reconozco señales sutiles en el entorno","valor":4,"nivel":" N1","dimension":"Intuición","tipo":"Normal"},{"item":59,"pregunta":" Confío en mi percepción interna","valor":4,"nivel":" N2","dimension":"Intuición","tipo":"Normal"},{"item":60,"pregunta":" Me desconecto de mis sensaciones internas","valor":4,"nivel":" N2 ","dimension":"Intuición","tipo":"Invertida"},{"item":61,"pregunta":" Mantengo atención en tareas importantes","valor":4,"nivel":" N1","dimension":"Enfoque","tipo":"Normal"},{"item":62,"pregunta":" Me distraigo con facilidad","valor":4,"nivel":" N1 ","dimension":"Enfoque","tipo":"Invertida"},{"item":63,"pregunta":" Prioritizo actividades relevantes","valor":4,"nivel":" N1","dimension":"Enfoque","tipo":"Normal"},{"item":64,"pregunta":" Completo lo que inicio","valor":4,"nivel":" N3","dimension":"Enfoque","tipo":"Normal"},{"item":65,"pregunta":" Mantengo disciplina personal","valor":4,"nivel":" N3","dimension":"Enfoque","tipo":"Normal"},{"item":66,"pregunta":" Me concentro incluso en entornos distractores","valor":3,"nivel":" N1","dimension":"Enfoque","tipo":"Normal"},{"item":67,"pregunta":" Postergó tareas importantes","valor":3,"nivel":" N3 ","dimension":"Enfoque","tipo":"Invertida"},{"item":68,"pregunta":" Administro bien mi tiempo","valor":4,"nivel":" N3","dimension":"Enfoque","tipo":"Normal"},{"item":69,"pregunta":" Mantengo claridad en mis objetivos","valor":4,"nivel":" N1","dimension":"Enfoque","tipo":"Normal"},{"item":70,"pregunta":" Abandono metas fácilmente","valor":3,"nivel":" N3 ","dimension":"Enfoque","tipo":"Invertida"},{"item":71,"pregunta":" Controlo mis impulsos emocionales","valor":4,"nivel":" N3","dimension":"Regulación Emocional","tipo":"Normal"},{"item":72,"pregunta":" Reformulo pensamientos negativos","valor":4,"nivel":" N1","dimension":"Regulación Emocional","tipo":"Normal"},{"item":73,"pregunta":" Busco soluciones en lugar de reaccionar","valor":3,"nivel":" N3","dimension":"Regulación Emocional","tipo":"Normal"},{"item":74,"pregunta":" Reacciono exageradamente ante problemas","valor":4,"nivel":" N3 ","dimension":"Regulación Emocional","tipo":"Invertida"},{"item":75,"pregunta":" Tolero frustraciones","valor":4,"nivel":" N2","dimension":"Regulación Emocional","tipo":"Normal"},{"item":76,"pregunta":" Regulo mi enojo adecuadamente","valor":3,"nivel":" N3","dimension":"Regulación Emocional","tipo":"Normal"},{"item":77,"pregunta":" Me cuesta manejar el estrés","valor":4,"nivel":" N2 ","dimension":"Regulación Emocional","tipo":"Invertida"},{"item":78,"pregunta":" Actúo con calma bajo presión","valor":3,"nivel":" N3","dimension":"Regulación Emocional","tipo":"Normal"},{"item":79,"pregunta":" Reflexiono antes de responder emocionalmente","valor":3,"nivel":" N1","dimension":"Regulación Emocional","tipo":"Normal"},{"item":80,"pregunta":" Evito enfrentar emociones difíciles","valor":4,"nivel":" N2 ","dimension":"Regulación Emocional","tipo":"Invertida"},{"item":81,"pregunta":" Tengo metas claras en mi vida","valor":4,"nivel":" N1","dimension":"Propósito","tipo":"Normal"},{"item":82,"pregunta":" Mi vida tiene sentido para mí","valor":4,"nivel":" N2","dimension":"Propósito","tipo":"Normal"},{"item":83,"pregunta":" Actúo alineado con mis objetivos","valor":4,"nivel":" N3","dimension":"Propósito","tipo":"Normal"},{"item":84,"pregunta":" Me siento perdido respecto a mi futuro","valor":4,"nivel":" N1 ","dimension":"Propósito","tipo":"Invertida"},{"item":85,"pregunta":" Trabajo por algo que considero significativo","valor":4,"nivel":" N3","dimension":"Propósito","tipo":"Normal"},{"item":86,"pregunta":" Identifico mi vocación","valor":4,"nivel":" N1","dimension":"Propósito","tipo":"Normal"},{"item":87,"pregunta":" Mis acciones reflejan mis aspiraciones","valor":4,"nivel":" N3","dimension":"Propósito","tipo":"Normal"},{"item":88,"pregunta":" Me falta dirección personal","valor":3,"nivel":" N1 ","dimension":"Propósito","tipo":"Invertida"},{"item":89,"pregunta":" Mantengo motivación interna","valor":4,"nivel":" N2","dimension":"Propósito","tipo":"Normal"},{"item":90,"pregunta":" Planifico mi crecimiento personal","valor":4,"nivel":" N1","dimension":"Propósito","tipo":"Normal"},{"item":91,"pregunta":" Siento conexión con algo más grande que yo","valor":4,"nivel":" N2","dimension":"Trascendencia Simbólica","tipo":"Normal"},{"item":92,"pregunta":" Reflexiono sobre el sentido profundo de la vida","valor":4,"nivel":" N1","dimension":"Trascendencia Simbólica","tipo":"Normal"},{"item":93,"pregunta":" Busco significado en experiencias difíciles","valor":4,"nivel":" N1","dimension":"Trascendencia Simbólica","tipo":"Normal"},{"item":94,"pregunta":" Me siento desconectado de lo trascendente","valor":3,"nivel":" N2 ","dimension":"Trascendencia Simbólica","tipo":"Invertida"},{"item":95,"pregunta":" Experimento paz interior","valor":4,"nivel":" N2","dimension":"Trascendencia Simbólica","tipo":"Normal"},{"item":96,"pregunta":" Integro valores espirituales en mi vida","valor":4,"nivel":" N3","dimension":"Trascendencia Simbólica","tipo":"Normal"},{"item":97,"pregunta":" Encuentro propósito en el sufrimiento","valor":2,"nivel":" N1","dimension":"Trascendencia Simbólica","tipo":"Normal"},{"item":98,"pregunta":" Vivo sin cuestionar el sentido de la existencia","valor":4,"nivel":" N1 ","dimension":"Trascendencia Simbólica","tipo":"Invertida"},{"item":99,"pregunta":" Siento unidad con mi entorno","valor":3,"nivel":" N2","dimension":"Trascendencia Simbólica","tipo":"Normal"},{"item":100,"pregunta":" Practico momentos de introspección profunda","valor":3,"nivel":" N3","dimension":"Trascendencia Simbólica","tipo":"Normal"},{"item":101,"pregunta":" Genero ideas originales con facilidad","valor":4,"nivel":" N1","dimension":"Creatividad","tipo":"Normal"},{"item":102,"pregunta":" Busco soluciones innovadoras","valor":4,"nivel":" N1","dimension":"Creatividad","tipo":"Normal"},{"item":103,"pregunta":" Me adapto creativamente a problemas","valor":3,"nivel":" N3","dimension":"Creatividad","tipo":"Normal"},{"item":104,"pregunta":" Me cuesta pensar fuera de lo común","valor":3,"nivel":" N1 ","dimension":"Creatividad","tipo":"Invertida"},{"item":105,"pregunta":" Disfruto imaginar posibilidades nuevas","valor":4,"nivel":" N2","dimension":"Creatividad","tipo":"Normal"},{"item":106,"pregunta":" Transformo errores en oportunidades","valor":4,"nivel":" N3","dimension":"Creatividad","tipo":"Normal"},{"item":107,"pregunta":" Exploro perspectivas poco convencionales","valor":4,"nivel":" N1","dimension":"Creatividad","tipo":"Normal"},{"item":108,"pregunta":" Evito asumir riesgos creativos","valor":3,"nivel":" N3 ","dimension":"Creatividad","tipo":"Invertida"},{"item":109,"pregunta":" Conecto ideas diferentes entre sí","valor":4,"nivel":" N1","dimension":"Creatividad","tipo":"Normal"},{"item":110,"pregunta":" Expreso mi creatividad activamente","valor":4,"nivel":" N3","dimension":"Creatividad","tipo":"Normal"},{"item":111,"pregunta":" Vivo el momento actual conscientemente","valor":4,"nivel":" N2","dimension":"Presencia","tipo":"Normal"},{"item":112,"pregunta":" Mi mente se dispersa constantemente","valor":4,"nivel":" N1 ","dimension":"Presencia","tipo":"Invertida"},{"item":113,"pregunta":" Soy consciente de mis sensaciones corporales","valor":4,"nivel":" N2","dimension":"Presencia","tipo":"Normal"},{"item":114,"pregunta":" Escucho con atención plena","valor":3,"nivel":" N3","dimension":"Presencia","tipo":"Normal"},{"item":115,"pregunta":" Disfruto experiencias sin distraerme","valor":3,"nivel":" N2","dimension":"Presencia","tipo":"Normal"},{"item":116,"pregunta":" Me anticipo constantemente al futuro","valor":4,"nivel":" N1 ","dimension":"Presencia","tipo":"Invertida"},{"item":117,"pregunta":" Observo mis pensamientos sin juzgarlos","valor":4,"nivel":" N1","dimension":"Presencia","tipo":"Normal"},{"item":118,"pregunta":" Mantengo atención plena en conversaciones","valor":3,"nivel":" N3","dimension":"Presencia","tipo":"Normal"},{"item":119,"pregunta":" Me desconecto fácilmente del presente","valor":3,"nivel":" N1 ","dimension":"Presencia","tipo":"Invertida"},{"item":120,"pregunta":" Practico la atención consciente","valor":4,"nivel":" N3","dimension":"Presencia","tipo":"Normal"},{"item":121,"pregunta":" Actúo conforme a mis valores","valor":4,"nivel":" N3","dimension":"Ética Interna","tipo":"Normal"},{"item":122,"pregunta":" Reflexiono sobre lo correcto antes de decidir","valor":4,"nivel":" N1","dimension":"Ética Interna","tipo":"Normal"},{"item":123,"pregunta":" Mantengo coherencia entre lo que digo y hago","valor":4,"nivel":" N3","dimension":"Ética Interna","tipo":"Normal"},{"item":124,"pregunta":" Justifico conductas incorrectas","valor":4,"nivel":" N1 ","dimension":"Ética Interna","tipo":"Invertida"},{"item":125,"pregunta":" Me responsabilizo de mis actos","valor":4,"nivel":" N3","dimension":"Ética Interna","tipo":"Normal"},{"item":126,"pregunta":" Evalúo consecuencias morales","valor":4,"nivel":" N1","dimension":"Ética Interna","tipo":"Normal"},{"item":127,"pregunta":" Defiendo principios aunque sea difícil","valor":4,"nivel":" N3","dimension":"Ética Interna","tipo":"Normal"},{"item":128,"pregunta":" Cambio valores según conveniencia","valor":3,"nivel":" N1 ","dimension":"Ética Interna","tipo":"Invertida"},{"item":129,"pregunta":" Busco justicia en mis decisiones","valor":4,"nivel":" N2","dimension":"Ética Interna","tipo":"Normal"},{"item":130,"pregunta":" Actúo con integridad","valor":4,"nivel":" N3","dimension":"Ética Interna","tipo":"Normal"},{"item":131,"pregunta":" Mantengo equilibrio entre pensamiento y emoción","valor":4,"nivel":" N1","dimension":"Integración Personal","tipo":"Normal"},{"item":132,"pregunta":" Mis acciones reflejan mis creencias","valor":4,"nivel":" N3","dimension":"Integración Personal","tipo":"Normal"},{"item":133,"pregunta":" Siento coherencia interna","valor":3,"nivel":" N2","dimension":"Integración Personal","tipo":"Normal"},{"item":134,"pregunta":" Vivo en conflicto interno frecuente","valor":3,"nivel":" N2 ","dimension":"Integración Personal","tipo":"Invertida"},{"item":135,"pregunta":" Integro aprendizajes en mi vida diaria","valor":4,"nivel":" N3","dimension":"Integración Personal","tipo":"Normal"},{"item":136,"pregunta":" Me adapto sin perder mi identidad","valor":4,"nivel":" N1","dimension":"Integración Personal","tipo":"Normal"},{"item":137,"pregunta":" Me siento fragmentado internamente","valor":4,"nivel":" N2 ","dimension":"Integración Personal","tipo":"Invertida"},{"item":138,"pregunta":" Mantengo estabilidad en distintas áreas de mi vida","valor":4,"nivel":" N3","dimension":"Integración Personal","tipo":"Normal"},{"item":139,"pregunta":" Actúo alineado con mi propósito","valor":4,"nivel":" N3","dimension":"Integración Personal","tipo":"Normal"},{"item":140,"pregunta":" Reconozco desequilibrios internos","valor":4,"nivel":" N1","dimension":"Integración Personal","tipo":"Normal"},{"item":141,"pregunta":" Pienso,siento y actúo de manera congruente","valor":4,"nivel":" N3","dimension":"Coherencia Interna","tipo":"Normal"},{"item":142,"pregunta":" Identifico contradicciones en mí","valor":4,"nivel":" N1","dimension":"Coherencia Interna","tipo":"Normal"},{"item":143,"pregunta":" Ajusto mis acciones cuando no son coherentes","valor":4,"nivel":" N3","dimension":"Coherencia Interna","tipo":"Normal"},{"item":144,"pregunta":" Me comporto distinto según conveniencia","valor":3,"nivel":" N3 ","dimension":"Coherencia Interna","tipo":"Invertida"},{"item":145,"pregunta":" Mantengo consistencia en mis decisiones","valor":4,"nivel":" N1","dimension":"Coherencia Interna","tipo":"Normal"},{"item":146,"pregunta":" Reconozco cuando traiciono mis valores","valor":4,"nivel":" N1","dimension":"Coherencia Interna","tipo":"Normal"},{"item":147,"pregunta":" Corrijo incoherencias personales","valor":4,"nivel":" N3","dimension":"Coherencia Interna","tipo":"Normal"},{"item":148,"pregunta":" Cambio postura sin fundamento claro","valor":4,"nivel":" N1 ","dimension":"Coherencia Interna","tipo":"Invertida"},{"item":149,"pregunta":" Busco alineación interna constante","valor":4,"nivel":" N2","dimension":"Coherencia Interna","tipo":"Normal"},{"item":150,"pregunta":" Me percibo como una persona íntegra","valor":4,"nivel":" N2","dimension":"Coherencia Interna","tipo":"Normal"}
Respuestas_PD = pd.DataFrame(Array_Respuesta)

# %%
valores = list(Respuestas_PD["valor"])

for i in range(0, len(valores), 10):
    print(f'{i} - {valores[i:i+10]}')
# Out:
# 0 - [3, 4, 4, 4, 4, 3, 2, 4, 4, 2]
# 10 - [4, 4, 4, 4, 4, 3, 3, 4, 4, 3]
# 20 - [4, 4, 3, 4, 5, 5, 4, 3, 4, 4]
# 30 - [4, 5, 5, 5, 4, 5, 3, 4, 4, 5]
# 40 - [5, 5, 4, 3, 4, 4, 4, 4, 3, 3]
# 50 - [4, 4, 3, 3, 4, 3, 3, 4, 4, 4]
# 60 - [4, 4, 4, 4, 4, 3, 3, 4, 4, 3]
# 70 - [4, 4, 3, 4, 4, 3, 4, 3, 3, 4]
# 80 - [4, 4, 4, 4, 4, 4, 4, 3, 4, 4]
# 90 - [4, 4, 4, 3, 4, 4, 2, 4, 3, 3]
# 100 - [4, 4, 3, 3, 4, 4, 4, 3, 4, 4]
# 110 - [4, 4, 4, 3, 3, 4, 4, 3, 3, 4]
# 120 - [4, 4, 4, 4, 4, 4, 4, 3, 4, 4]
# 130 - [4, 4, 3, 3, 4, 4, 4, 4, 4, 4]
# 140 - [4, 4, 4, 3, 4, 4, 4, 4, 4, 4]
